# %% [markdown]
# ### First code in python

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Indendation
#
# - Indendation in Python is used to indicate a block of code.

# %%
if 5 > 2:
    print("Five is greater than two")
# Out:
# Five is greater than Two

# %% [markdown]
# ### Comments

# %%
# This is a comment 
print("Python Class")
# Out:
# Python Class

# %% [markdown]
# ### Statements
# - Statement is a Programming instruction.

# %%
print("Good Morning") # Good Morning is a statement.
# Out:
# Good Morning

# %% [markdown]
# ## Task 1
# - Write a statement to print hello world.
# - Write a statement to print Good Morning.
# - Write a statement to print Good Night.

# %%
#Soln

print("Hello World")
print("Good Morning")
print("Good Night")
# Out:
# Hello World
# Good Morning
# Good Night

# %% [markdown]
# ## Output/ Print
# - We use print() to get output.
# ```
# print("Output")
# ```
# #### Number
# - We dont need to us "" to print number.
# ```
# print(7)
# ```
# ### Mix Text and Numbers
# - If we need combined text and number in one output them we need to separate them by comma.
# ```
# print("Text",5)
# ```
# ### end
# - end parameter is used to print statements on a same line.
# ```
# print("Python is Fun", end= " " )
# print("Hello Word")
# ```

# %%
print("Visit Nepal")
print(2020)
print("Visit Nepal",2020)
print("Visit Nepal", end= " " ) # end parameter is used to print statements on a same line.
print("2020")
# Out:
# Visit Nepal
# 2020
# Visit Nepal 2020
# Visit Nepal 2020

# %% [markdown]
# ## Task 2
# - print the text I am and number 20 in one print statement.

# %%
#Soln

print("I am", end=" ")
print(20)
# Out:
# I am 20

# %% [markdown]
# ## Comment in python
# - Comment is used to explain python code.
# - Comment is used to make code more readable.
# - Comment is used to prevent execution when testing code.

# %%
# this is single line comment
print("Single line Comment")

"""
this is multline comment 
"""
print("Multiline comment")
# Out:
# Single line Comment
# Multiline comment

# %% [markdown]
# ## Task 3
# - Add a single line comment that say This is comment.
# - Comment out the line print("This should not run") so it doesnot execuite.
# - Add a multiline comment thet say this is multiline comment.

# %%
#soln
#This is a comment
#print("This should not run")
"""
This is 
a mutiline 
comment
"""
# Out:
# '\nThis is mutiline comment\n'
